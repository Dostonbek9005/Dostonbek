# %% [markdown]
# <a href="https://colab.research.google.com/github/Dostonbek9005/Dostonbek/blob/main/Untitled55.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, marker = 'o')
plt.show()
plt.plot(ypoints, 'o:r')
plt.show()
plt.plot(ypoints, marker = '*', ms = 20, mec = 'r')
plt.show()
plt.plot(ypoints, linestyle = 'dotted')
plt.show()
plt.plot(ypoints, linewidth = '20.5')
plt.show()
